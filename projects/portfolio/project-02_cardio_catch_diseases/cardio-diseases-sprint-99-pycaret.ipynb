# %% [markdown]
# ### **D2APR: Aprendizado de Máquina e Reconhecimento de Padrões** (IFSP, Campinas) <br/>
# **Prof**: Samuel Martins (Samuka) <br/>
#
# <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png" /></a><br />This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>. <br/><br/>

# %% [markdown]
# #### Custom CSS style

# %%
# %%html
# <style>
# .dashed-box {
#     border: 1px dashed black !important;
# #    font-size: var(--jp-content-font-size1) !important;
# }
#
# .dashed-box table {
#
# }
#
# .dashed-box tr {
#     background-color: white !important;
# }
#
# .alt-tab {
#     background-color: black;
#     color: #ffc351;
#     padding: 4px;
#     font-size: 1em;
#     font-weight: bold;
#     font-family: monospace;
# }
# // add your CSS styling here
# </style>
# Out:
# <style>
# .dashed-box {
#     border: 1px dashed black !important;
# #    font-size: var(--jp-content-font-size1) !important;
# }
#
# .dashed-box table {
#
# }
#
# .dashed-box tr {
#     background-color: white !important;
# }
#
# .alt-tab {
#     background-color: black;
#     color: #ffc351;
#     padding: 4px;
#     font-size: 1em;
#     font-weight: bold;
#     font-family: monospace;
# }
# // add your CSS styling here
# </style>

# %% [markdown]
# <span style='font-size: 2.5em'><b>Cardiovascular Disease 💔</b></span><br/>
# <span style='font-size: 1.5em'>Predict cardiovascular diseases</span>
#
# <span style="background-color: #ffc351; padding: 4px; font-size: 1em;"><b>Sprint #?? - Draft</b></span>
#
# <img src="./imgs/cardio.png" width=300/>
#
# ---

# %% [markdown]
# ## Before starting this notebook
# This jupyter notebook is designed for **experimental and teaching purposes**. <br/>
# Although it is (relatively) well organized, it aims at solving the _target problem_ by evaluating (and documenting) _different solutions_ for somes steps of the **machine learning pipeline** — see the [***Machine Learning Project Checklist by xavecoding***](https://github.com/xavecoding/IFSP-CMP-D2APR-2021.2/blob/main/cheat-sheets/machine-learning-project-checklist_by_xavecoding.pdf). <br/>
# We tried to make this notebook as literally a _notebook_. Thus, it contains notes, drafts, comments, etc.<br/>
#
# For teaching purposes, some parts of the notebook may be _overcommented_. Moreover, to simulate a real development scenario, we will divide our solution and experiments into **"sprints"** in which each sprint has some goals (e.g., perform _feature selection_, train more ML models, ...). <br/>
# The **sprint goal** will be stated at the beginning of the notebook.
#
# A ***final notebook*** (or any other kind of presentation) that compiles and summarizes all sprints — the target problem, solutions, and findings — should be created later.
#
# #### Conventions
#
# <ul>
#     <li>💡 indicates a tip. </li>
#     <li> ⚠️ indicates a warning message. </li>
#     <li><span class='alt-tab'>alt tab</span> indicates and an extra content (<i>e.g.</i>, slides) to explain a given concept.</li>
# </ul>
#
# ---

# %% [markdown]
# ## 🎯 Sprint Goals
# - Evaluate on the training set:
#   + Linear SVM
#   + SVM Polynomial Kernel
#   + SVM RBF Kernel
# ---

# %% [markdown]
# ### 0. Imports and default settings for plotting

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")

params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 5),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
plt.rcParams.update(params)

# %% [markdown]
# ### 🏋️‍♀️ 6. Train ML Algorithms

# %% [markdown]
# #### [PyCaret](https://pycaret.org/guide/)
# Installation - https://pycaret.readthedocs.io/en/latest/installation.html <br/>
# Toy example for Binary Classification - https://github.com/pycaret/pycaret/blob/master/tutorials/Binary%20Classification%20Tutorial%20Level%20Beginner%20-%20%20CLF101.ipynb

# %%
cardio_train = pd.read_csv('./datasets/cardio_clean_train.csv')

# %%
cardio_train
# Out:
#          age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0      21875       2     171    74.0    120     80            1     1      0
# 1      15302       1     162    66.0    110     80            1     1      0
# 2      18079       1     166    69.0    120     80            1     2      0
# 3      21680       1     169    65.0    120     80            1     1      0
# 4      14368       1     155    80.0    120     80            1     1      0
# ...      ...     ...     ...     ...    ...    ...          ...   ...    ...
# 54715  19137       2     178    99.0    150    100            1     1      0
# 54716  19649       1     170    65.0    110     70            1     1      0
# 54717  18056       1     165    67.0    120     80            1     1      0
# 54718  20321       1     161    64.0    150     90            2     1      0
# 54719  19033       2     173    60.0    120     80            1     1      1
#
#        alco  active  cardio
# 0         0       0       1
# 1         0       1       0
# 2         0       1       0
# 3         0       0       1
# 4         0       1       0
# ...     ...     ...     ...
# 54715     0       1       1
# 54716     0       0       0
# 54717     0       1       0
# 54718     0       1       1
# 54719     0       1       0
#
# [54720 rows x 12 columns]

# %%
from pycaret.classification import *
exp_clf101 = setup(data=cardio_train,
                   target='cardio',
                   train_size=0.8,
                   session_id=123,
                   normalize=True,
                   numeric_imputation='median',
                   normalize_method='robust',
                   fold=5)
# Out:
# <style  type="text/css" >
# #T_386c8_row29_col1,#T_386c8_row44_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_386c8_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_386c8_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_386c8_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_386c8_row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_386c8_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_386c8_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_386c8_row1_col1" class="data row1 col1" >cardio</td>
#             </tr>
#             <tr>
#                         <th id="T_386c8_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_386c8_row2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_386c8_row2_col1" class="data row2 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_386c8_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_386c8_row3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_386c8_row3_col1" class="data row3 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_386c8_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_386c8_row4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_386c8_row4_col1" class="data row4 col1" >(54720, 12)</td>
#             </tr>
#             <tr>
#                         <th id="T_386c8_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_386c8_row5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_386c8_row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_386c8_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_386c8_row6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_386c8_row6_col1" class="data row6 col1" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_386c8_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_386c8_row7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_386c8_row7_col1" class="data row7 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_386c8_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_386c8_row8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_386c8_row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_386c8_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_386c8_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_386c8_row9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_386c8_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_386c8_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_386c8_row10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_386c8_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_386c8_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_386c8_row11_col1" class="data row11 col1" >(43776, 15)</td>
#             </tr>
#             <tr>
#                         <th id="T_386c8_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_386c8_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_386c8_row12_col1" class="data row12 col1" >(10944, 15)</td>
#             </tr>
#             <tr>
#                         <th id="T_386c8_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_386c8_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_386c8_row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_386c8_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_386c8_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_386c8_row14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_386c8_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_386c8_row15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_386c8_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_386c8_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_386c8_row16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_386c8_row16_col1" class="data row16 col1" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_386c8_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_386c8_row17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_386c8_row17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_386c8_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_386c8_row18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_386c8_row18_col1" class="data row18 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_386c8_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_386c8_row19_col0" class="data row19 col0" >Log Experiment</td>
#                         <td id="T_386c8_row19_col1" class="data row19 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_386c8_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_386c8_row20_col0" class="data row20 col0" >Experiment Name</td>
#                         <td id="T_386c8_row20_col1" class="data row20 col1" >clf-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_386c8_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_386c8_row21_col0" class="data row21 col0" >USI</td>
#                         <td id="T_386c8_row21_col1" class="data row21 col1" >f155</td>
#             </tr>
#             <tr>
#                         <th id="T_386c8_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_386c8_row22_col0" class="data row22 col0" >Imputation Type</td>
#                         <td id="T_386c8_row22_col1" class="data row22 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_386c8_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_386c8_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_386c8_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_386c8_level0_row24" class="row_heading le

# %%
best_model = compare_models()
# Out:
# <style  type="text/css" >
#     #T_847d6_ th {
#           text-align: left;
#     }#T_847d6_row0_col0,#T_847d6_row0_col4,#T_847d6_row1_col0,#T_847d6_row1_col1,#T_847d6_row1_col2,#T_847d6_row1_col3,#T_847d6_row1_col4,#T_847d6_row1_col5,#T_847d6_row1_col6,#T_847d6_row1_col7,#T_847d6_row2_col0,#T_847d6_row2_col1,#T_847d6_row2_col2,#T_847d6_row2_col3,#T_847d6_row2_col5,#T_847d6_row2_col6,#T_847d6_row2_col7,#T_847d6_row3_col0,#T_847d6_row3_col1,#T_847d6_row3_col2,#T_847d6_row3_col3,#T_847d6_row3_col4,#T_847d6_row3_col5,#T_847d6_row3_col6,#T_847d6_row3_
_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#                         <td id="T_847d6_row0_col1" class="data row0 col1" >0.7352</td>
#                         <td id="T_847d6_row0_col2" class="data row0 col2" >0.8009</td>
#                         <td id="T_847d6_row0_col3" class="data row0 col3" >0.6991</td>
#                         <td id="T_847d6_row0_col4" class="data row0 col4" >0.7489</td>
#                         <td id="T_847d6_row0_col5" class="data row0 col5" >0.7231</td>
#                         <td id="T_847d6_row0_col6" class="data row0 col6" >0.4699</td>
#                         <td id="T_847d6_row0_col7" class="data row0 col7" >0.4710</td>
#                         <td id="T_847d6_row0_col8" class="data row0 col8" >0.5700</td>
#             </tr>
#             <tr>
#                         <th id="T_847d6_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#                         <td id="T_847d6_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_847d6_row1_col1" class="data row1 col1" >0.7347</td>
#                         <td id="T_847d6_row1_col2" class="data row1 col2" >0.7996</td>
#                         <td id="T_847d6_row1_col3" class="data row1 col3" >0.6961</td>
#                         <td id="T_847d6_row1_col4" class="data row1 col4" >0.7498</td>
#                         <td id="T_847d6_row1_col5" class="data row1 col5" >0.7219</td>
#                         <td id="T_847d6_row1_col6" class="data row1 col6" >0.4690</td>
#                         <td id="T_847d6_row1_col7" class="data row1 col7" >0.4702</td>
#                         <td id="T_847d6_row1_col8" class="data row1 col8" >0.1500</td>
#             </tr>
#             <tr>
#                         <th id="T_847d6_level0_row2" class="row_heading level0 row2" >ada</th>
#                         <td id="T_847d6_row2_col0" class="data row2 col0" >Ada Boost Classifier</td>
#                         <td id="T_847d6_row2_col1" class="data row2 col1" >0.7286</td>
#                         <td id="T_847d6_row2_col2" class="data row2 col2" >0.7937</td>
#                         <td id="T_847d6_row2_col3" class="data row2 col3" >0.6528</td>
#                         <td id="T_847d6_row2_col4" class="data row2 col4" >0.7643</td>
#                         <td id="T_847d6_row2_col5" class="data row2 col5" >0.7042</td>
#                         <td id="T_847d6_row2_col6" class="data row2 col6" >0.4564</td>
#                         <td id="T_847d6_row2_col7" class="data row2 col7" >0.4612</td>
#                         <td id="T_847d6_row2_col8" class="data row2 col8" >0.1880</td>
#             </tr>
#             <tr>
#                         <th id="T_847d6_level0_row3" class="row_heading level0 row3" >lr</th>
#                         <td id="T_847d6_row3_col0" class="data row3 col0" >Logistic Regression</td>
#                         <td id="T_847d6_row3_col1" class="data row3 col1" >0.7284</td>
#                         <td id="T_847d6_row3_col2" class="data row3 col2" >0.7922</td>
#                         <td id="T_847d6_row3_col3" class="data row3 col3" >0.6677</td>
#                         <td id="T_847d6_row3_col4" class="data row3 col4" >0.7550</td>
#                         <td id="T_847d6_row3_col5" class="data row3 col5" >0.7087</td>
#                         <td id="T_847d6_row3_col6" class="data row3 col6" >0.4562</td>
#                         <td id="T_847d6_row3_col7" class="data row3 col7" >0.4592</td>
#                         <td id="T_847d6_row3_col8" class="data row3 col8" >0.2360</td>
#             </tr>
#             <tr>
#                         <th id="T_847d6_level0_row4" class="row_heading level0 row4" >svm</th>
#                         <td id="T_847d6_row4_col0" class="data row4 col0" >SVM - Linear Kernel</td>
#                         <td id="T_847d6_row4_col1" class="data row4 col1" >0.7267</td>
#                         <td id="T_847d6_row4_col2" class="data row4 col2" >0.0000</td>
#                         <td id="T_847d6_row4_col3" class="data row4 col3" >0.6633</td>
#                         <td id="T_847d6_row4_col4" class="data row4 col4" >0.7580</td>
#                         <td id="T_847d6_row4_col5" class="data row4 col5" >0.7051</td>
#                         <td id="T_847d6_row4_col6" class=
